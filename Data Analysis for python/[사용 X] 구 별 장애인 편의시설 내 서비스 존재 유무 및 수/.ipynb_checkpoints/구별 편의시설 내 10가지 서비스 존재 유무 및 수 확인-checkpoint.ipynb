# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 서울시 관광편의시설 데이터 읽기
df = pd.read_csv('[데이터] 관광편의시설정보 시설별 분류(전처리완료).csv')

# 필요한 데이터만 추출 (담당구 제외하고 Y/N 형태의 자료)
df = df[['담당구', '주출입구 접근로 여부', '주출입구 높이차이 제거 여부',
        '장애인용 승강기 여부', '장애인 화장실 여부', '장애인용 관람석 이용가능 여부',
        '장애인 매표소 여부', '시각장애인 편의서비스 여부', '청각장애인 편의서비스 여부',
        '안내 서비스 여부', '휠체어 대여 여부']]

# %%
# 각 구별 해당 관광편의시설의 서비스의 제공 여부
pd.DataFrame(df.groupby(['담당구', '주출입구 접근로 여부']).size())

# 2548개의 데이터 중 Y에 해당하는 10개의 서비스 개수 (막대그래프) ...
# Out:
#                     0
# 담당구  주출입구 접근로 여부
# 강남구  N              2
#      Y            119
# 강동구  N             23
#      Y             94
# 강북구  N              7
#      Y             58
# 강서구  N             27
#      Y            170
# 관악구  N              2
#      Y             94
# 광진구  N              4
#      Y             58
# 구로구  N              8
#      Y             95
# 금천구  N             22
#      Y             88
# 노원구  N             30
#      Y            139
# 도봉구  N             20
#      Y             83
# 동대문구 N              7
#      Y             66
# 동작구  N              1
#      Y            106
# 마포구  N             22
#      Y             53
# 서대문구 N              8
#      Y             96
# 서초구  N              1
#      Y             45
# 성동구  N              2
#      Y             99
# 성북구  N             32
#      Y             76
# 송파구  N              4
#      Y            142
# 양천구  N             19
#      Y             96
# 영등포구 N              4
#      Y             90
# 용산구  N              5
#      Y             69
# 은평구  N             11
#      Y            128
# 종로구  N             23
#      Y             57
# 중구   N              1
#      Y             19
# 중랑구  N             14
#      Y            109

# %%
# 보류
plt.pie(df['주출입구 접근로 여부'].value_counts())
plt.show()

# %%
# 구별 편의시설 내 서비스 존재유무를 피봇테이블로 구현
df.pivot_table(df, index='담당구', aggfunc='count', margins=True)
# Out:
#       시각장애인 편의서비스 여부  안내 서비스 여부  장애인 매표소 여부  장애인 화장실 여부  장애인용 관람석 이용가능 여부  \
# 담당구
# 강남구              121        121         121         121               121
# 강동구              117        117         117         117               117
# 강북구               65         65          65          65                65
# 강서구              197        197         197         197               197
# 관악구               96         96          96          96                96
# 광진구               62         62          62          62                62
# 구로구              103        103         103         103               103
# 금천구              110        110         110         110               110
# 노원구              169        169         169         169               169
# 도봉구              103        103         103         103               103
# 동대문구              73         73          73          73                73
# 동작구              107        107         107         107               107
# 마포구               75         75          75          75                75
# 서대문구             104        104         104         104               104
# 서초구               46         46          46          46                46
# 성동구              101        101         101         101               101
# 성북구              108        108         108         108               108
# 송파구              146        146         146         146               146
# 양천구              115        115         115         115               115
# 영등포구              94         94          94          94                94
# 용산구               74         74          74          74                74
# 은평구              139        139         139         139               139
# 종로구               80         80          80          80                80
# 중구                20         20          20          20                20
# 중랑구              123        123         123         123               123
# All             2548       2548        2548        2548              2548
#
#       장애인용 승강기 여부  주출입구 높이차이 제거 여부  주출입구 접근로 여부  청각장애인 편의서비스 여부  휠체어 대여 여부
# 담당구
# 강남구           121              121          121             121        121
# 강동구           117              117          117             117        117
# 강북구            65               65           65              65         65
# 강서구           197              197          197             197        197
# 관악구            96               96           96              96         96
# 광진구            62               62           62              62         62
# 구로구           103              103          103             103        103
# 금천구           110              110          110             110        110
# 노원구           169              169          169             169        169
# 도봉구           103              103          103             103        103
# 동대문구           73               73           73              73         73
# 동작구           107              107          107             107        107
# 마포구            75               75           75              75         75
# 서대문구          104              104          104             104        104
# 서초구            46               46           46              46         46
# 성동구           101              101          101             101        101
# 성북구           108              108          108             108        108
# 송파구           146              146          146             146        146
# 양천구           115              115          115             115        115
# 영등포구           94               94           94              94         94
# 용산구            74               74           74              74         74
# 은평구           139              139          139             139        139
# 종로구            80               80           80              80         80
# 중구             20               20           20              20         20
# 중랑구           123              123          123             123        123
# All          2548             2548         2548            2548       2548
