# %%
import pandas as pd
import folium
# Out:
#   File "<ipython-input-16-24bf79b76035>", line 1
#     pip install folium
#         ^
# SyntaxError: invalid syntax

# %%
# 서울시 관광편의시설 데이터 읽기
df = pd.read_csv('[데이터] 관광편의시설정보 시설별 분류(전처리완료).csv')
df.head()
# Out:
#    Unnamed: 0  고유번호      시설명   담당구                    주소           연락처  \
# 0           0   720  신당동 우체국    중구         서울시 중구 다동길 11  02-2236-0606
# 1          15  5515  동대문문화회관  동대문구  서울시 동대문구 답십리로  210-9  02-2241-9300
# 2          21  4743     용산구청   용산구     서울시 용산구 녹사평대로 150  02-2199-6114
# 3          35  4798    서대문구청  서대문구      서울시 서대문구 연희로 248   02-330-1114
# 4          37  4802     경찰청사  서대문구      서울시 서대문구 통일로  97           NaN
#
#                              홈페이지  추천수 주출입구 접근로 여부 주출입구 높이차이 제거 여부  ...  \
# 0                             NaN    0           Y               Y  ...
# 1                             NaN    0           Y               Y  ...
# 2       http://www.yongsan.go.kr/    0           Y               Y  ...
# 3  http://www.seodaemun.seoul.kr/    0           Y               Y  ...
# 4                             NaN    0           Y               Y  ...
#
#   장애인 화장실 여부 장애인용 관람석 이용가능 여부 장애인 매표소 여부 시각장애인 편의서비스 여부 청각장애인 편의서비스 여부  \
# ...

# %%
# 구별 편의시설 갯수 세기
fac_counts = df['담당구'].value_counts()
fac_counts
# Out:
# 강서구     197
# 노원구     169
# 송파구     146
# 은평구     139
# 중랑구     123
# 강남구     121
# 강동구     117
# 양천구     115
# 금천구     110
# 성북구     108
# 동작구     107
# 서대문구    104
# 도봉구     103
# 구로구     103
# 성동구     101
# 관악구      96
# 영등포구     94
# 종로구      80
# 마포구      75
# 용산구      74
# 동대문구     73
# 강북구      65
# 광진구      62
# 서초구      46
# 중구       20
# Name: 담당구, dtype: int64
